# %%
# Import the dependencies.
import pandas as pd
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
# Import the requests library.
import requests
import time
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 722

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
 
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        #print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        #for weather description
        city_weather_info = city_weather["weather"]
        city_weather_description = city_weather_info[0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          })

#If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | port alfred
# Processing Record 3 of Set 1 | broken hill
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | porto novo
# Processing Record 7 of Set 1 | hamilton
# Processing Record 8 of Set 1 | baghdad
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | nenjiang
# Processing Record 11 of Set 1 | twentynine palms
# Processing Record 12 of Set 1 | minab
# Processing Record 13 of Set 1 | kashi
# Processing Record 14 of Set 1 | vao
# Processing Record 15 of Set 1 | esperance
# Processing Record 16 of Set 1 | kuala sungai baru
# Processing Record 17 of Set 1 | laguna
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | qasigiannguit
# Processing Record 22 of Set 1 | ust-kut
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | jamestown
# Processing Record 25 of Set 1 | whithorn
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | kristiansund
# Processing Record 28 of Set 1 | punta arenas
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | thompson
# Processing Record 31 of Set 1 | tasiilaq
# Processing Record 32 of Set 1 | lebu
# Processing Record 33 of Set 1 | ust-tarka
# Processing Record 34 of Set 1 | turukhansk
# Processing Record 35 of Set 1 | hovd
# Processing Record 36 of Set 1 | pevek
# Processing Record 37 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 1 | geraldton
# Processing Record 39 of Set 1 | winnipeg
# Processing Record 40 of Set 1 | jalu
# Processing Record 41 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | arraial do cabo
# Processing Record 44 of Set 1 | paso de carrasco
# Processing Record 45 of Set 1 | inhambane
# Processing Record 46 of Set 1 | tari
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | bodo
# Processing Record 49 of Set 1 | floro
# Processing Record 50 of Set 1 | vestmannaeyjar
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | hobart
# Processing Record 3 of Set 2 | hojai
# Processing Record 4 of Set 2 | narsaq
# Processing Record 5 of Set 2 | lianzhou
# Processing Record 6 of Set 2 | rikitea
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | jiangyou
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 2 | adrar
# Processing Record 12 of Set 2 | ranong
# Processing Record 13 of Set 2 | ahuimanu
# Processing Record 14 of Set 2 | port elizabeth
# Processing Record 15 of Set 2 | mahajanga
# Processing Record 16 of Set 2 | kupang
# Processing Record 17 of Set 2 | poum
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | livingston
# Processing Record 20 of Set 2 | longyearbyen
# Processing Record 21 of Set 2 | zlitan
# Processing Record 22 of Set 2 | upernavik
# Processing Record 23 of Set 2 | new norfolk
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | port blair
# Processing Record 26 of Set 2 | kudahuvadhoo
# Processing Record 27 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 2 | port lincoln
# Processing Record 29 of Set 2 | san jose
# Processing Record 30 of Set 2 | haines junction
# Processing Record 31 of Set 2 | mabaruma
# Processing Record 32 of Set 2 | marsh harbour
# Processing Record 33 of Set 2 | saldanha
# Processing Record 34 of Set 2 | tulum
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | dong hoi
# Processing Record 39 of Set 2 | bengkulu
# Processing Record 40 of Set 2 | kirakira
# Processing Record 41 of Set 2 | jieshi
# Processing Record 42 of Set 2 | vila velha
# Processing Record 43 of Set 2 | pichayevo
# Processing Record 44 of Set 2 | navalmoral de la mata
# Processing Record 45 of Set 2 | shambu
# Processing Record 46 of Set 2 | yellowknife
# Processing Record 47 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 2 | ribeira grande
# Processing Record 49 of Set 2 | lara
# Processing Record 50 of Set 2 | touros
# Processing Record 1 of Set 3 | broome
# Processing Record 2 of Set 3 | khorixas
# Processing Record 3 of Set 3 | grand gaube
# Processing Record 4 of Set 3 | kavieng
# Processing Record 5 of Set 3 | cabo san lucas
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | rabo de peixe
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | sao filipe
# Processing Record 11 of Set 3 | coihaique
# Processing Record 12 of Set 3 | svetlyy
# Processing Record 13 of Set 3 | bilma
# Processing Record 14 of Set 3 | port hedland
# Processing Record 15 of Set 3 | wuda
# Processing Record 16 of Set 3 | stromness
# Processing Record 17 of Set 3 | bababe
# City not found. Skipping...
# Processing Record 18 of Set 3 | zhigansk
# Processing Record 19 of Set 3 | phan thiet
# Processing Record 20 of Set 3 | cape town
# Processing Record 21 of Set 3 | brainerd
# Processing Record 22 of Set 3 | khatanga
# Processing Record 23 of Set 3 | hithadhoo
# Processing Record 24 of Set 3 | srednekolymsk
# Processing Record 25 of Set 3 | asau
# Processing Record 26 of Set 3 | cherskiy
# Processing Record 27 of Set 3 | leh
# Processing Record 28 of Set 3 | portland
# Processing Record 29 of Set 3 | bambous virieux
# Processing Record 30 of Set 3 | sobolevo
# Processing Record 31 of Set 3 | lapusnicel
# Processing Record 32 of Set 3 | kijang
# Processing Record 33 of Set 3 | mwanza
# Processing Record 34 of Set 3 | alyangula
# Processing Record 35 of Set 3 | soyo
# Processing Record 36 of Set 3 | caravelas
# Processing Record 37 of Set 3 | berlevag
# Processing Record 38 of Set 3 | kaitangata
# Processing Record 39 of Set 3 | burns lake
# Processing Record 40 of Set 3 | maneromango
# Processing Record 41 of Set 3 | waw
# Processing Record 42 of Set 3 | samana
# Processing Record 43 of Set 3 | houma
# Processing Record 44 of Set 3 | sirjan
# Processing Record 45 of Set 3 | takab
# Processing Record 46 of Set 3 | balabac
# Processing Record 47 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 3 | kruisfontein
# Processing Record 49 of Set 3 | garachine
# Processing Record 50 of Set 3 | itoman
# Processing Record 1 of Set 4 | qarayeri
# Processing Record 2 of Set 4 | saint anthony
# Processing Record 3 of Set 4 | tamluk
# Processing Record 4 of Set 4 | maloshuyka
# City not found. Skipping...
# Processing Record 5 of Set 4 | georgetown
# Processing Record 6 of Set 4 | tucuma
# Processing Record 7 of Set 4 | wilmington
# Processing Record 8 of Set 4 | pa daet
# Processing Record 9 of Set 4 | santa luzia
# Processing Record 10 of Set 4 | san patricio
# Processing Record 11 of Set 4 | vila franca do campo
# Processing Record 12 of Set 4 | lorengau
# Processing Record 13 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 4 | klaksvik
# Processing Record 15 of Set 4 | tanggu
# Processing Record 16 of Set 4 | palasa
# Processing Record 17 of Set 4 | pisco
# Processing Record 18 of Set 4 | ca mau
# Processing Record 19 of Set 4 | pangnirtung
# Processing Record 20 of Set 4 | ashta
# Processing Record 21 of Set 4 | rocha
# Processing Record 22 of Set 4 | christchurch
# Processing Record 23 of Set 4 | rawson
# Processing Record 24 of Set 4 | camargo
# Processing Record 25 of Set 4 | salina cruz
# Processing Record 26 of Set 4 | bonavista
# Processing Record 27 of Set 4 | glace bay
# Processing Record 28 of Set 4 | mareeba
# Processing Record 29 of Set 4 | springdale
# Processing Record 30 of Set 4 | kawalu
# Processing Record 31 of Set 4 | lages
# Processing Record 32 of Set 4 | tiksi
# Processing Record 33 of Set 4 | lompoc
# Processing Record 34 of Set 4 | namibe
# Processing Record 35 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 4 | borlange
# City not found. Skipping...
# Processing Record 37 of Set 4 | vanavara
# Processing Record 38 of Set 4 | rancho palos verdes
# Processing Record 39 of Set 4 | wucheng
# Processing Record 40 of Set 4 | saint-philippe
# Processing Record 41 of Set 4 | clyde river
# Processing Record 42 of Set 4 | san vicente
# Processing Record 43 of Set 4 | severo-kurilsk
# Processing Record 44 of Set 4 | mar del plata
# Processing Record 45 of Set 4 | ilam
# Processing Record 46 of Set 4 | huarmey
# Processing Record 47 of Set 4 | kalmunai
# Processing Record 48 of Set 4 | taoudenni
# Processing Record 49 of Set 4 | carnarvon
# Processing Record 50 of Set 4 | invercargill
# Processing Record 1 of Set 5 | luena
# Processing Record 2 of Set 5 | changtu
# Processing Record 3 of Set 5 | kailua
# Processing Record 4 of Set 5 | korla
# Processing Record 5 of Set 5 | goundam
# Processing Record 6 of Set 5 | hornepayne
# Processing Record 7 of Set 5 | potamia
# Processing Record 8 of Set 5 | kuching
# Processing Record 9 of Set 5 | dolinsk
# Processing Record 10 of Set 5 | guiratinga
# Processing Record 11 of Set 5 | kodiak
# Processing Record 12 of Set 5 | owando
# Processing Record 13 of Set 5 | saskylakh
# Processing Record 14 of Set 5 | ilulissat
# Processing Record 15 of Set 5 | lewisporte
# Processing Record 16 of Set 5 | mgandu
# Processing Record 17 of Set 5 | ambanja
# Processing Record 18 of Set 5 | fort nelson
# Processing Record 19 of Set 5 | constitucion
# Processing Record 20 of Set 5 | ratnagiri
# Processing Record 21 of Set 5 | airai
# Processing Record 22 of Set 5 | bandarbeyla
# Processing Record 23 of Set 5 | raton
# Processing Record 24 of Set 5 | chokurdakh
# Processing Record 25 of Set 5 | noyabrsk
# Processing Record 26 of Set 5 | saint george
# Processing Record 27 of Set 5 | saint-joseph
# Processing Record 28 of Set 5 | dingle
# Processing Record 29 of Set 5 | azimur
# City not found. Skipping...
# Processing Record 30 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 5 | blagoveshchenka
# Processing Record 32 of Set 5 | tura
# Processing Record 33 of Set 5 | mogadishu
# Processing Record 34 of Set 5 | puerto ayora
# Processing Record 35 of Set 5 | hokitika
# Processing Record 36 of Set 5 | katsuura
# Processing Record 37 of Set 5 | grindavik
# Processing Record 38 of Set 5 | srandakan
# Processing Record 39 of Set 5 | cairns
# Processing Record 40 of Set 5 | amapa
# Processing Record 41 of Set 5 | iqaluit
# Processing Record 42 of Set 5 | alofi
# Processing Record 43 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 44 of Set 5 | kattivakkam
# Processing Record 45 of Set 5 | cidreira
# Processing Record 46 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 5 | vardo
# Processing Record 48 of Set 5 | luderitz
# Processing Record 49 of Set 5 | talnakh
# Processing Record 50 of Set 5 | nemuro
# Processing Record 1 of Set 6 | beringovskiy
# Processing Record 2 of Set 6 | aanekoski
# Processing Record 3 of Set 6 | viedma
# Processing Record 4 of Set 6 | naze
# Processing Record 5 of Set 6 | margate
# Processing Record 6 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 6 | hastings
# Processing Record 8 of Set 6 | provideniya
# Processing Record 9 of Set 6 | aksay
# Processing Record 10 of Set 6 | carbonia
# Processing Record 11 of Set 6 | tautira
# Processing Record 12 of Set 6 | tuensang
# Processing Record 13 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 6 | bac lieu
# Processing Record 15 of Set 6 | desbiens
# Processing Record 16 of Set 6 | tres arroyos
# Processing Record 17 of Set 6 | hami
# Processing Record 18 of Set 6 | nikolskoye
# Processing Record 19 of Set 6 | palmer
# Processing Record 20 of Set 6 | fortuna
# Processing Record 21 of Set 6 | victoria
# Processing Record 22 of Set 6 | fomboni
# Processing Record 23 of Set 6 | weinan
# Processing Record 24 of Set 6 | maputo
# Processing Record 25 of Set 6 | safaga
# Processing Record 26 of Set 6 | camacha
# Processing Record 27 of Set 6 | atbasar
# Processing Record 28 of Set 6 | kutum
# Processing Record 29 of Set 6 | belmonte
# Processing Record 30 of Set 6 | diego de almagro
# Processing Record 31 of Set 6 | mount isa
# Processing Record 32 of Set 6 | souillac
# Processing Record 33 of Set 6 | biak
# Processing Record 34 of Set 6 | birin
# Processing Record 35 of Set 6 | afmadu
# City not found. Skipping...
# Processing Record 36 of Set 6 | la rioja
# Processing Record 37 of Set 6 | nakambala
# Processing Record 38 of Set 6 | morant bay
# Processing Record 39 of Set 6 | crowley
# Processing Record 40 of Set 6 | curanilahue
# Processing Record 41 of Set 6 | pringsewu
# Processing Record 42 of Set 6 | cambridge
# Processing Record 43 of Set 6 | kerki
# City not found. Skipping...
# Processing Record 44 of Set 6 | half moon bay
# Processing Record 45 of Set 6 | bethel
# Processing Record 46 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 6 | manaus
# Processing Record 48 of Set 6 | saint-ambroise
# Processing Record 49 of Set 6 | ornskoldsvik
# Processing Record 50 of Set 6 | eskasem
# City not found. Skipping...
# Processing Record 1 of Set 7 | mount gambier
# Processing Record 2 of Set 7 | flinders
# Processing Record 3 of Set 7 | tuy hoa
# Processing Record 4 of Set 7 | maoming
# Processing Record 5 of Set 7 | shingu
# Processing Record 6 of Set 7 | hirara
# Processing Record 7 of Set 7 | kamir
# Processing Record 8 of Set 7 | los llanos de aridane
# Processing Record 9 of Set 7 | garowe
# Processing Record 10 of Set 7 | lumsden
# Processing Record 11 of Set 7 | westport
# Processing Record 12 of Set 7 | bam
# Processing Record 13 of Set 7 | coquimbo
# Processing Record 14 of Set 7 | kongolo
# Processing Record 15 of Set 7 | trairi
# Processing Record 16 of Set 7 | mount lebanon
# Processing Record 17 of Set 7 | norman wells
# Processing Record 18 of Set 7 | toyooka
# Processing Record 19 of Set 7 | deputatskiy
# Processing Record 20 of Set 7 | nchelenge
# Processing Record 21 of Set 7 | edson
# Processing Record 22 of Set 7 | ewa beach
# Processing Record 23 of Set 7 | asfi
# Processing Record 24 of Set 7 | torbay
# Processing Record 25 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 27 of Set 7 | sao joao da barra
# Processing Record 28 of Set 7 | batticaloa
# Processing Record 29 of Set 7 | ayan
# Processing Record 30 of Set 7 | artyk
# City not found. Skipping...
# Processing Record 31 of Set 7 | kommunar
# Processing Record 32 of Set 7 | bulaevo
# Processing Record 33 of Set 7 | zaraza
# Processing Record 34 of Set 7 | papasquiaro
# City not found. Skipping...
# Processing Record 35 of Set 7 | darnah
# Processing Record 36 of Set 7 | kapit
# Processing Record 37 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 38 of Set 7 | aquiraz
# Processing Record 39 of Set 7 | ilukste
# Processing Record 40 of Set 7 | roebourne
# Processing Record 41 of Set 7 | dothan
# Processing Record 42 of Set 7 | tual
# Processing Record 43 of Set 7 | luan
# Processing Record 44 of Set 7 | havre-saint-pierre
# Processing Record 45 of Set 7 | santa cruz
# Processing Record 46 of Set 7 | san felipe
# Processing Record 47 of Set 7 | college
# Processing Record 48 of Set 7 | codrington
# Processing Record 49 of Set 7 | north platte
# Processing Record 50 of Set 7 | sioux lookout
# Processing Record 1 of Set 8 | yaan
# Processing Record 2 of Set 8 | teahupoo
# Processing Record 3 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 8 | roald
# Processing Record 5 of Set 8 | de-kastri
# Processing Record 6 of Set 8 | vestmanna
# Processing Record 7 of Set 8 | chuy
# Processing Record 8 of Set 8 | bilibino
# Processing Record 9 of Set 8 | burla
# Processing Record 10 of Set 8 | khuzdar
# Processing Record 11 of Set 8 | tazovskiy
# Processing Record 12 of Set 8 | wakkanai
# Processing Record 13 of Set 8 | okha
# Processing Record 14 of Set 8 | niceville
# Processing Record 15 of Set 8 | arman
# Processing Record 16 of Set 8 | barra do garcas
# Processing Record 17 of Set 8 | masyaf
# Processing Record 18 of Set 8 | la romana
# Processing Record 19 of Set 8 | praya
# Processing Record 20 of Set 8 | bontang
# Processing Record 21 of Set 8 | crab hill
# City not found. Skipping...
# Processing Record 22 of Set 8 | qujing
# Processing Record 23 of Set 8 | alta floresta
# Processing Record 24 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 8 | mendeleyevo
# Processing Record 26 of Set 8 | corinto
# Processing Record 27 of Set 8 | chernyshevskiy
# Processing Record 28 of Set 8 | yeppoon
# Processing Record 29 of Set 8 | turayf
# Processing Record 30 of Set 8 | savasleyka
# Processing Record 31 of Set 8 | faya
# Processing Record 32 of Set 8 | henties bay
# Processing Record 33 of Set 8 | kologriv
# Processing Record 34 of Set 8 | musoma
# Processing Record 35 of Set 8 | montepuez
# Processing Record 36 of Set 8 | komsomolskiy
# Processing Record 37 of Set 8 | leningradskiy
# Processing Record 38 of Set 8 | faanui
# Processing Record 39 of Set 8 | sakaiminato
# Processing Record 40 of Set 8 | te anau
# Processing Record 41 of Set 8 | ancud
# Processing Record 42 of Set 8 | khandyga
# Processing Record 43 of Set 8 | bonthe
# Processing Record 44 of Set 8 | tiarei
# Processing Record 45 of Set 8 | skjervoy
# Processing Record 46 of Set 8 | leme
# Processing Record 47 of Set 8 | salalah
# Processing Record 48 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 8 | richards bay
# Processing Record 1 of Set 9 | karratha
# Processing Record 2 of Set 9 | ponta do sol
# Processing Record 3 of Set 9 | ende
# Processing Record 4 of Set 9 | kahului
# Processing Record 5 of Set 9 | kenai
# Processing Record 6 of Set 9 | jacareacanga
# Processing Record 7 of Set 9 | namatanai
# Processing Record 8 of Set 9 | esso
# Processing Record 9 of Set 9 | neka
# Processing Record 10 of Set 9 | baker
# Processing Record 11 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 12 of Set 9 | sitka
# Processing Record 13 of Set 9 | la gaulette
# City not found. Skipping...
# Processing Record 14 of Set 9 | zhanaozen
# Processing Record 15 of Set 9 | varhaug
# Processing Record 16 of Set 9 | hofn
# Processing Record 17 of Set 9 | tokur
# Processing Record 18 of Set 9 | tabas
# Processing Record 19 of Set 9 | sinjah
# City not found. Skipping...
# Processing Record 20 of Set 9 | champerico
# Processing Record 21 of Set 9 | waipawa
# Processing Record 22 of Set 9 | pontianak
# Processing Record 23 of Set 9 | marystown
# Processing Record 24 of Set 9 | cayenne
# Processing Record 25 of Set 9 | yumbe
# Processing Record 26 of Set 9 | bolekhiv
# Processing Record 27 of Set 9 | kauhajoki
# Processing Record 28 of Set 9 | tunduru
# City not found. Skipping...
# Processing Record 29 of Set 9 | port hardy
# Processing Record 30 of Set 9 | matara
# Processing Record 31 of Set 9 | lar
# Processing Record 32 of Set 9 | grand island
# Processing Record 33 of Set 9 | tubruq
# City not found. Skipping...
# Processing Record 34 of Set 9 | nalut
# Processing Record 35 of Set 9 | praia da vitoria
# Processing Record 36 of Set 9 | aquin
# Processing Record 37 of Set 9 | lima
# Processing Record 38 of Set 9 | hanmer springs
# Processing Record 39 of Set 9 | sungairaya
# Processing Record 40 of Set 9 | skovorodino
# Processing Record 41 of Set 9 | san quintin
# Processing Record 42 of Set 9 | chipinge
# Processing Record 43 of Set 9 | shchuchye
# City not found. Skipping...
# Processing Record 44 of Set 9 | ardahan
# Processing Record 45 of Set 9 | makakilo city
# Processing Record 46 of Set 9 | katangli
# Processing Record 47 of Set 9 | shangrao
# Processing Record 48 of Set 9 | sur
# Processing Record 49 of Set 9 | lata
# Processing Record 50 of Set 9 | acapulco
# Processing Record 1 of Set 10 | qaqortoq
# Processing Record 2 of Set 10 | coxim
# Processing Record 3 of Set 10 | koscierzyna
# Processing Record 4 of Set 10 | berezovka
# Processing Record 5 of Set 10 | mugur-aksy
# Processing Record 6 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 10 | whitehorse
# Processing Record 8 of Set 10 | takoradi
# Processing Record 9 of Set 10 | bograd
# Processing Record 10 of Set 10 | vostok
# Processing Record 11 of Set 10 | bulgan
# Processing Record 12 of Set 10 | nadym
# Processing Record 13 of Set 10 | ludvika
# Processing Record 14 of Set 10 | seoul
# Processing Record 15 of Set 10 | plouzane
# Processing Record 16 of Set 10 | la ronge
# Processing Record 17 of Set 10 | ixtapa
# Processing Record 18 of Set 10 | damietta
# Processing Record 19 of Set 10 | tarauaca
# Processing Record 20 of Set 10 | troitskoye
# Processing Record 21 of Set 10 | khabary
# Processing Record 22 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 10 | whitianga
# Processing Record 24 of Set 10 | urucara
# Processing Record 25 of Set 10 | yenagoa
# Processing Record 26 of Set 10 | havelock
# Processing Record 27 of Set 10 | saint-georges
# Processing Record 28 of Set 10 | athabasca
# Processing Record 29 of Set 10 | tupik
# Processing Record 30 of Set 10 | bathsheba
# Processing Record 31 of Set 10 | sola
# Processing Record 32 of Set 10 | ketchikan
# Processing Record 33 of Set 10 | puerto cabezas
# Processing Record 34 of Set 10 | manzhouli
# Processing Record 35 of Set 10 | hegra
# Processing Record 36 of Set 10 | saint-francois
# Processing Record 37 of Set 10 | santa barbara
# Processing Record 38 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 10 | nelson bay
# Processing Record 40 of Set 10 | ouesso
# Processing Record 41 of Set 10 | santa rosalia
# Processing Record 42 of Set 10 | sambava
# Processing Record 43 of Set 10 | cruzeiro
# Processing Record 44 of Set 10 | totoral
# Processing Record 45 of Set 10 | mega
# Processing Record 46 of Set 10 | dhenkanal
# Processing Record 47 of Set 10 | naryan-mar
# Processing Record 48 of Set 10 | pauini
# Processing Record 49 of Set 10 | sisimiut
# Processing Record 50 of Set 10 | sabang
# Processing Record 1 of Set 11 | lebowakgomo
# Processing Record 2 of Set 11 | paamiut
# Processing Record 3 of Set 11 | biltine
# Processing Record 4 of Set 11 | kieta
# Processing Record 5 of Set 11 | mangit
# Processing Record 6 of Set 11 | corrales
# Processing Record 7 of Set 11 | karaman
# Processing Record 8 of Set 11 | oriximina
# Processing Record 9 of Set 11 | tubuala
# Processing Record 10 of Set 11 | mier
# Processing Record 11 of Set 11 | elizabeth city
# Processing Record 12 of Set 11 | ipaussu
# Processing Record 13 of Set 11 | ibra
# Processing Record 14 of Set 11 | bath
# Processing Record 15 of Set 11 | griffith
# Processing Record 16 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 17 of Set 11 | bardiyah
# Processing Record 18 of Set 11 | vredendal
# Processing Record 19 of Set 11 | disna
# Processing Record 20 of Set 11 | pitimbu
# Processing Record 21 of Set 11 | novyy urengoy
# Processing Record 22 of Set 11 | marawi
# Processing Record 23 of Set 11 | sorong
# Processing Record 24 of Set 11 | kiama
# Processing Record 25 of Set 11 | sao felix do xingu
# Processing Record 26 of Set 11 | lusambo
# Processing Record 27 of Set 11 | ekhabi
# Processing Record 28 of Set 11 | adre
# Processing Record 29 of Set 11 | paraiso
# Processing Record 30 of Set 11 | gejiu
# Processing Record 31 of Set 11 | moundou
# Processing Record 32 of Set 11 | tecolutla
# Processing Record 33 of Set 11 | maningrida
# Processing Record 34 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 35 of Set 11 | mayo
# Processing Record 36 of Set 11 | zalantun
# Processing Record 37 of Set 11 | cockburn town
# Processing Record 38 of Set 11 | maldonado
# Processing Record 39 of Set 11 | anadyr
# Processing Record 40 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 41 of Set 11 | baykit
# Processing Record 42 of Set 11 | celestun
# Processing Record 43 of Set 11 | lichuan
# Processing Record 44 of Set 11 | nioaque
# Processing Record 45 of Set 11 | dalbandin
# Processing Record 46 of Set 11 | mattru
# Processing Record 47 of Set 11 | wanparti
# Processing Record 48 of Set 11 | belyy yar
# Processing Record 49 of Set 11 | lasa
# Processing Record 50 of Set 11 | kavaratti
# Processing Record 1 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 12 | sinnamary
# Processing Record 3 of Set 12 | ellensburg
# Processing Record 4 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 5 of Set 12 | keshan
# City not found. Skipping...
# Processing Record 6 of Set 12 | nioro
# Processing Record 7 of Set 12 | merauke
# Processing Record 8 of Set 12 | rae bareli
# Processing Record 9 of Set 12 | satun
# Processing Record 10 of Set 12 | dharmanagar
# Processing Record 11 of Set 12 | flin flon
# Processing Record 12 of Set 12 | mombetsu
# Processing Record 13 of Set 12 | paso de los toros
# Processing Record 14 of Set 12 | colborne
# Processing Record 15 of Set 12 | cerrito
# Processing Record 16 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 17 of Set 12 | cap-aux-meules
# Processing Record 18 of Set 12 | surt
# Processing Record 19 of Set 12 | soure
# Processing Record 20 of Set 12 | pleasanton
# Processing Record 21 of Set 12 | sheltozero
# Processing Record 22 of Set 12 | mehamn
# Processing Record 23 of Set 12 | luau
# Processing Record 24 of Set 12 | walvis bay
# Processing Record 25 of Set 12 | khoy
# Processing Record 26 of Set 12 | yerbogachen
# Processing Record 27 of Set 12 | mulchen
# Processing Record 28 of Set 12 | karakol
# Processing Record 29 of Set 12 | thilogne
# City not found. Skipping...
# Processing Record 30 of Set 12 | tamandare
# Processing Record 31 of Set 12 | melville
# Processing Record 32 of Set 12 | hasaki
# Processing Record 33 of Set 12 | alpena
# Processing Record 34 of Set 12 | verkhnyaya toyma
# Processing Record 35 of Set 12 | muros
# Processing Record 36 of Set 12 | isangel
# Processing Record 37 of Set 12 | wanning
# Processing Record 38 of Set 12 | leshukonskoye
# Processing Record 39 of Set 12 | amahai
# Processing Record 40 of Set 12 | almenevo
# City not found. Skipping...
# Processing Record 41 of Set 12 | nhulunbuy
# Processing Record 42 of Set 12 | krasnoselkup
# Processing Record 43 of Set 12 | oboyan
# Processing Record 44 of Set 12 | awjilah
# Processing Record 45 of Set 12 | qeshm
# Processing Record 46 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 47 of Set 12 | sakakah
# Processing Record 48 of Set 12 | coyah
# Processing Record 49 of Set 12 | dunedin
# Processing Record 50 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 13 | cao bang
# Processing Record 2 of Set 13 | rio de jesus
# Processing Record 3 of Set 13 | mitsamiouli
# Processing Record 4 of Set 13 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 5 of Set 13 | methoni
# Processing Record 6 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 7 of Set 13 | pasni
# Processing Record 8 of Set 13 | angoche
# Processing Record 9 of Set 13 | staroaleyskoye
# Processing Record 10 of Set 13 | doka
# Processing Record 11 of Set 13 | hualmay
# Processing Record 12 of Set 13 | gushikawa
# Processing Record 13 of Set 13 | san policarpo
# Processing Record 14 of Set 13 | kidal
# Processing Record 15 of Set 13 | caucaia
# Processing Record 16 of Set 13 | olafsvik
# Processing Record 17 of Set 13 | puerto madryn
# Processing Record 18 of Set 13 | pangoa
# Processing Record 19 of Set 13 | mapiripan
# Processing Record 20 of Set 13 | muzaffarabad
# Processing Record 21 of Set 13 | tabou
# Processing Record 22 of Set 13 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 23 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 24 of Set 13 | chicama
# Processing Record 25 of Set 13 | plainview
# Processing Record 26 of Set 13 | bay roberts
# Processing Record 27 of Set 13 | nador
# Processing Record 28 of Set 13 | sept-iles
# Processing Record 29 of Set 13 | staraya poltavka
# Processing Record 30 of Set 13 | vigrestad
# Processing Record 31 of Set 13 | east london
# Processing Record 32 of Set 13 | luangwa
# Processing Record 33 of Set 13 | severo-yeniseyskiy
# Processing Record 34 of Set 13 | thaba-tseka
# Processing Record 35 of Set 13 | port-gentil
# Processing Record 36 of Set 13 | mirnyy
# Processing Record 37 of Set 13 | saint-pierre
# Processing Record 38 of Set 13 | vila
# Processing Record 39 of Set 13 | yelatma
# Processing Record 40 of Set 13 | meppel
# Processing Record 41 of Set 13 | pacific grove
# Processing Record 42 of Set 13 | veracruz
# Processing Record 43 of Set 13 | krasnovishersk
# Processing Record 44 of Set 13 | manjacaze
# Processing Record 45 of Set 13 | nianzishan
# Processing Record 46 of Set 13 | gazli
# Processing Record 47 of Set 13 | maarianhamina
# Processing Record 48 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 13 | mouila
# Processing Record 50 of Set 13 | ondjiva
# Processing Record 1 of Set 14 | bang saphan
# Processing Record 2 of Set 14 | ostrovnoy
# Processing Record 3 of Set 14 | abha
# Processing Record 4 of Set 14 | santa maria
# Processing Record 5 of Set 14 | olinda
# Processing Record 6 of Set 14 | salamiyah
# Processing Record 7 of Set 14 | longonjo
# Processing Record 8 of Set 14 | lao cai
# Processing Record 9 of Set 14 | nanortalik
# Processing Record 10 of Set 14 | goderich
# Processing Record 11 of Set 14 | tahta
# Processing Record 12 of Set 14 | berberati
# Processing Record 13 of Set 14 | liverpool
# Processing Record 14 of Set 14 | nome
# Processing Record 15 of Set 14 | xiangdong
# City not found. Skipping...
# Processing Record 16 of Set 14 | manado
# Processing Record 17 of Set 14 | tuim
# Processing Record 18 of Set 14 | tamworth
# Processing Record 19 of Set 14 | pitsunda
# Processing Record 20 of Set 14 | kerugoya
# Processing Record 21 of Set 14 | ensley
# Processing Record 22 of Set 14 | lavrentiya
# Processing Record 23 of Set 14 | dekar
# Processing Record 24 of Set 14 | lagoa
# Processing Record 25 of Set 14 | novoagansk
# Processing Record 26 of Set 14 | tottori
# Processing Record 27 of Set 14 | give
# Processing Record 28 of Set 14 | kayerkan
# Processing Record 29 of Set 14 | villarrica
# Processing Record 30 of Set 14 | san cristobal
# Processing Record 31 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 32 of Set 14 | katherine
# Processing Record 33 of Set 14 | yueyang
# Processing Record 34 of Set 14 | odienne
# Processing Record 35 of Set 14 | raga
# Processing Record 36 of Set 14 | plettenberg bay
# Processing Record 37 of Set 14 | cochrane
# Processing Record 38 of Set 14 | muzhi
# Processing Record 39 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 40 of Set 14 | moron
# Processing Record 41 of Set 14 | girau do ponciano
# Processing Record 42 of Set 14 | chapais
# Processing Record 43 of Set 14 | el zulia
# Processing Record 44 of Set 14 | chivay
# Processing Record 45 of Set 14 | dhone
# Processing Record 46 of Set 14 | dakoro
# Processing Record 47 of Set 14 | pinega
# Processing Record 48 of Set 14 | kintinku
# Processing Record 49 of Set 14 | seydi
# Processing Record 50 of Set 14 | port macquarie
# Processing Record 1 of Set 15 | nisia floresta
# Processing Record 2 of Set 15 | santa helena de goias
# Processing Record 3 of Set 15 | tessalit
# Processing Record 4 of Set 15 | akureyri
# Processing Record 5 of Set 15 | charters towers
# Processing Record 6 of Set 15 | temyasovo
# Processing Record 7 of Set 15 | auki
# Processing Record 8 of Set 15 | balad
# Processing Record 9 of Set 15 | valdez
# Processing Record 10 of Set 15 | creel
# Processing Record 11 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 12 of Set 15 | kurtalan
# Processing Record 13 of Set 15 | manokwari
# Processing Record 14 of Set 15 | poyarkovo
# Processing Record 15 of Set 15 | norrtalje
# Processing Record 16 of Set 15 | babaeski
# Processing Record 17 of Set 15 | nahrin
# Processing Record 18 of Set 15 | khromtau
# Processing Record 19 of Set 15 | beitbridge
# Processing Record 20 of Set 15 | melfi
# Processing Record 21 of Set 15 | yeniseysk
# Processing Record 22 of Set 15 | ambodifototra
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Butaritari      KI   3.0707  172.7902     81.10        74          72
# 1          Lagoa      PT  39.0500  -27.9833     58.21        67          94
# 2     Oranjemund      NA -28.5500   16.4333     78.04        60          71
# 3        Rikitea      PF -23.1203 -134.9692     77.88        72         100
# 4        Mataura      NZ -46.1927  168.8643     54.48        88          32
# 5   Port Lincoln      AU -34.7333  135.8667     67.66        97          33
# 6  Alice Springs      AU -23.7000  133.8833     80.15        74          75
# 7        Fortuna      US  40.5982 -124.1573     46.74        93           0
# 8           Ibra      OM  22.6906   58.5334     64.62        39           0
# 9      Kavaratti      IN  10.5669   72.6420     79.84        68          87
#
#    Wind Speed Current Description
# 0       15.79       broken clouds
# 1       11.41     overcast clouds
# 2        8.97       broken clouds
# 3       11.05     overcast clouds
# 4        5.01    scattered clouds
# 5        7.70    scattered clouds
# 6        5.75        thunderstorm
# 7        8.05           clear sky
# 8        9.26           clear sky
# 9        9.17     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
